# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
responses = pd.read_csv('./../db/results-survey278342.csv', usecols=[7,8,11,13,14,15,16,17,18,19,21,22,23,24,25,26])

# %%
responses = responses.rename({"WhatisOA[SQ001]": "Literature"}, axis = "columns")
responses = responses.rename({"WhatisOA[SQ002]": "Courses"}, axis = "columns")
responses = responses.rename({"WhatisOA[SQ003]": "Software"}, axis = "columns")
responses = responses.rename({"WhatisOA[SQ004]": "Databases"}, axis = "columns")
responses = responses.rename({"WhatisOA[SQ005]": "Dknow"}, axis = "columns")

# %%
responses = responses.dropna(how="all")

# %%
responses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 0 to 105
# Data columns (total 16 columns):
# Age               88 non-null object
# MotherLanguage    85 non-null object
# AreaStudy         89 non-null object
# Level             89 non-null object
# Literature        89 non-null object
# Courses           89 non-null object
# Software          89 non-null object
# Databases         89 non-null object
# Dknow             89 non-null object
# HeardAboutIt      71 non-null object
# Importance        70 non-null object
# Legal             62 non-null object
# Paywall           65 non-null object
# SciHub            69 non-null object
# Unpaywall         69 non-null object
# Final             67 non-null object
# dtypes: object(16)
# memory usage: 11.8+ KB

# %% [markdown]
# # AGE

# %%
age = responses.Age.value_counts()
print(age)
age.plot.pie(title= "AGE", figsize=(7,7), autopct='%.1f%%');
plt.axis('off');
# Out:
# 18 - 24    48
# 25 - 29    15
# 45 - 49     7
# 30 - 34     7
# 35 - 39     5
# 40 - 44     2
# 60 - 64     2
# 55 - 59     1
# > 65        1
# Name: Age, dtype: int64

# %% [markdown]
# # Area of Study

# %%
area = responses.AreaStudy.value_counts()

# %%
print(area)
area.plot.pie(title="AREA OF STUDY", autopct='%.1f%%');
plt.axis('off');
# Out:
# Humanities, Arts and Social Sciences                77
# Science, Technology, Engineering, or Mathematics    12
# Name: AreaStudy, dtype: int64

# %% [markdown]
# # Mother Tongue

# %%
motherlanguage = responses.MotherLanguage.value_counts()

# %%
print(motherlanguage)
motherlanguage.plot.pie(title="MOTHER LANGAUGE", figsize=(7,7), autopct='%.1f%%');
plt.axis('off');
# Out:
# Portuguese    76
# Spanish        3
# French         2
# Polish         1
# Ukrainian      1
# Croatian       1
# English        1
# Name: MotherLanguage, dtype: int64

# %% [markdown]
# # Area

# %%
#level = responses.groupby('Level').count().Age.sort_values(ascending=False)
level = responses.Level.value_counts()

# %%
print(level)
level.plot.pie(title="LEVEL", autopct='%.1f%%', figsize=(10,10));
plt.axis('off');
# Out:
# Master                        28
# Undergraduate                 28
# Bachelor                      24
# PhD                            6
# Postdoc                        2
# Not In Academica right now     1
# Name: Level, dtype: int64

# %% [markdown]
# # What is Open Access?

# %%
#whatis = responses.groupby(['Literature','Courses','Software','Databases','Dknow']).count().Age

# %%
whatis = responses.loc[:,('Literature','Courses','Software','Databases','Dknow')]
whatis
# Out:
#     Literature Courses Software Databases Dknow
# 0          Yes      No      Yes       Yes    No
# 2          Yes      No       No       Yes    No
# 3          Yes     Yes      Yes       Yes    No
# 4           No      No       No        No   Yes
# 5           No      No       No        No   Yes
# ..         ...     ...      ...       ...   ...
# 100         No      No       No       Yes    No
# 102        Yes      No       No        No    No
# 103        Yes      No       No        No    No
# 104        Yes      No       No       Yes    No
# 105         No      No       No        No   Yes
#
# [89 rows x 5 columns]

# %%
flist = ['Literature','Courses','Software','Databases','Dknow']

for i in flist:
    #deprecated:
    #responses.groupby(i).count().Age.plot(kind="pie", autopct='%.1f%%')
    show = responses[i].value_counts()
    print(show)
    
    show.plot.pie( autopct='%.1f%%', title=i);
    plt.axis('off');
    plt.show()
# Out:
# No     48
# Yes    41
# Name: Literature, dtype: int64
# No     76
# Yes    13
# Name: Courses, dtype: int64
# No     69
# Yes    20
# Name: Software, dtype: int64
# Yes    48
# No     41
# Name: Databases, dtype: int64
# No     60
# Yes    29
# Name: Dknow, dtype: int64

# %% [markdown]
# # Heard About it

# %%
heardaboutit = responses.HeardAboutIt.value_counts()

# %%
print(heardaboutit)
heardaboutit.plot.pie(title="HEARD ABOUT IT", autopct='%.1f%%');
plt.axis('off');
# Out:
# Yes    42
# No     29
# Name: HeardAboutIt, dtype: int64

# %% [markdown]
# # Importance

# %%
importance = responses.Importance.value_counts()

# %%
print(importance)
importance.plot.pie(title="HOW IMPORTANT IS OA?", autopct='%.1f%%');
plt.axis('off');
# Out:
# Extremely     37
# Very          24
# Quite          7
# Not at all     1
# Barely         1
# Name: Importance, dtype: int64

# %%
legal = responses.Legal.value_counts()

# %%
print(legal)
legal.plot.pie(title="IS OA LEGAL?", autopct='%.1f%%');
plt.axis('off');
# Out:
# Legal      57
# Illegal     5
# Name: Legal, dtype: int64

# %% [markdown]
# # Paywall

# %%
paywall = responses.Paywall.value_counts()

# %%
print(paywall)
paywall.plot.pie(title="HAVE YOU EVER HIT A PAYWALL?", autopct='%.1f%%');
plt.axis('off');
# Out:
# Yes    52
# No     13
# Name: Paywall, dtype: int64

# %% [markdown]
# # SciHub

# %%
scihub = responses.SciHub.value_counts()

# %%
print(scihub)
scihub.plot.pie(title="HOW OFTEN DO YOU USE THE SCIHUB?", autopct='%.1f%%');
plt.axis('off');
# Out:
# Never heard of it    40
# Rarely               15
# Very often            7
# Often                 5
# Always                2
# Name: SciHub, dtype: int64

# %% [markdown]
# # Unpaywall

# %%
unpaywall = responses.Unpaywall.value_counts()

# %%
print(unpaywall)
unpaywall.plot.pie(title="HOW OFTEN DO YOU USE UNPAYWALL", autopct='%.1f%%');
plt.axis('off');
# Out:
# Never heard of it    44
# Often                10
# Always                7
# Very often            6
# Rarely                2
# Name: Unpaywall, dtype: int64

# %% [markdown]
# # Final

# %%
final = responses.Final.value_counts()

# %%
print(final)
final.plot.pie(title="WOULD YOU RATHER PUBLISH OPEN ACCESS OR ALL RIGHTS RESERVED?", autopct='%.1f%%');
plt.axis('off');
# Out:
# Open Access            39
# Doesn't know           16
# All Rights Reserved    12
# Name: Final, dtype: int64

# %%
comments = pd.read_csv('./../db/results-survey278342.csv', usecols=[20])

# %%
comments.dropna()
# Out:
#                                  HeardAboutIt[comment]
# 10                                     não falo inglês
# 12   i tought it was also making databases free, sorry
# 25                  You must fight to more open acesse
# 60   Penso que é muito importante para a realização...
# 97   I have only heard about Open Access in referen...
# 104  I heard about it and I know it's part of the "...

# %%
responses.tail(2)
# Out:
#          Age MotherLanguage                             AreaStudy   Level  \
# 104  25 - 29        Spanish  Humanities, Arts and Social Sciences  Master
# 105  25 - 29     Portuguese  Humanities, Arts and Social Sciences  Master
#
#     Literature Courses Software Databases Dknow HeardAboutIt Importance  \
# 104        Yes      No       No       Yes    No          Yes  Extremely
# 105         No      No       No        No   Yes           No  Extremely
#
#      Legal Paywall             SciHub          Unpaywall        Final
# 104  Legal     Yes  Never heard of it  Never heard of it  Open Access
# 105    NaN     Yes             Rarely  Never heard of it  Open Access

# %%
df= responses.loc[:,("Age","Level")]

# %%
df
# Out:
#          Age          Level
# 0    18 - 24  Undergraduate
# 2    18 - 24       Bachelor
# 3    30 - 34         Master
# 4    18 - 24       Bachelor
# 5    18 - 24       Bachelor
# ..       ...            ...
# 100  40 - 44            PhD
# 102  18 - 24       Bachelor
# 103  30 - 34         Master
# 104  25 - 29         Master
# 105  25 - 29         Master
#
# [89 rows x 2 columns]

# %%
tips = sns.load_dataset("./../db/results-survey278342.csv")
sns.catplot(x="Age", y="Level", data=tips);
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-ec02dd579295> in <module>
# ----> 1 tips = sns.load_dataset("./../db/results-survey278342.csv")
#       2 sns.catplot(x="Age", y="Level", data=tips);
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
